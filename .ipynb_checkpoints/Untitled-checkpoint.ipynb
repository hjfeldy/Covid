# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('http://data.cdc.gov/api/views/vbim-akqf/rows.csv?accessType=DOWNLOAD')
df
# Out:
# /home/harry/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          Unnamed: 0 cdc_report_dt pos_spec_dt    onset_dt  \
# 0                 0    2020/11/10  2020/11/10         NaN
# 1                 1    2020/11/14  2020/11/10  2020/11/10
# 2                 2    2020/11/19  2020/11/10  2020/11/09
# 3                 3    2020/11/14  2020/11/10         NaN
# 4                 4    2020/11/13  2020/11/10  2020/11/10
# ...             ...           ...         ...         ...
# 8405074     8405074    2020/10/22         NaN         NaN
# 8405075     8405075    2020/10/25         NaN         NaN
# 8405076     8405076    2020/07/18         NaN         NaN
# 8405077     8405077    2020/11/19         NaN         NaN
# 8405078     8405078    2020/11/03         NaN         NaN
#
#                     current_status      sex      age_group  \
# 0        Laboratory-confirmed case     Male  10 - 19 Years
# 1        Laboratory-confirmed case     Male  10 - 19 Years
# 2        Laboratory-confirmed case     Male  10 - 19 Years
# 3        Laboratory-confirmed case     Male  10 - 19 Years
# 4        Laboratory-confirmed case     Male  10 - 19 Years
# ...                            ...      ...            ...
# 8405074              Probable Case  Missing  30 - 39 Years
# 8405075  Laboratory-confirmed case  Missing  30 - 39 Years
# 8405076  Laboratory-confirmed case  Missing  30 - 39 Years
# 8405077  Laboratory-confirmed case  Missing  30 - 39 Years
# 8405078  Laboratory-confirmed case  Missing  30 - 39 Years
#
#         Race and ethnicity (combined)  hosp_yn   icu_yn death_yn medcond_yn
# 0                 Black, Non-Hispanic       No  Unknown       No         No
# 1                 Black, Non-Hispanic       No       No       No         No
# 2                 Black, Non-Hispanic       No       No       No         No
# 3                 Black, Non-Hispanic  Missing  Missing       No    Missing
# 4                 Black, Non-Hispanic       No       No       No        Yes
# ...                               ...      ...      ...      ...        ...
# 8405074                       Unknown       No  Unknown       No    Missing
# 8405075                       Unknown  Missing  Missing  Missing    Missing
# 8405076                       Unknown  Missing  Missing  Missing    Missing
# 8405077                       Unknown  Missing  Missing  Missing    Missing
# 8405078                       Unknown       No  Unknown       No    Missing
#
# [8405079 rows x 12 columns]

# %%
df = df.replace(['Missing', 'Unknown'], np.nan)
df = df.replace('No', 0)
df = df.replace('Yes', 1)
df
# Out:
#          Unnamed: 0 cdc_report_dt pos_spec_dt    onset_dt  \
# 0                 0    2020/11/10  2020/11/10         NaN
# 1                 1    2020/11/14  2020/11/10  2020/11/10
# 2                 2    2020/11/19  2020/11/10  2020/11/09
# 3                 3    2020/11/14  2020/11/10         NaN
# 4                 4    2020/11/13  2020/11/10  2020/11/10
# ...             ...           ...         ...         ...
# 8405074     8405074    2020/10/22         NaN         NaN
# 8405075     8405075    2020/10/25         NaN         NaN
# 8405076     8405076    2020/07/18         NaN         NaN
# 8405077     8405077    2020/11/19         NaN         NaN
# 8405078     8405078    2020/11/03         NaN         NaN
#
#                     current_status   sex      age_group  \
# 0        Laboratory-confirmed case  Male  10 - 19 Years
# 1        Laboratory-confirmed case  Male  10 - 19 Years
# 2        Laboratory-confirmed case  Male  10 - 19 Years
# 3        Laboratory-confirmed case  Male  10 - 19 Years
# 4        Laboratory-confirmed case  Male  10 - 19 Years
# ...                            ...   ...            ...
# 8405074              Probable Case   NaN  30 - 39 Years
# 8405075  Laboratory-confirmed case   NaN  30 - 39 Years
# 8405076  Laboratory-confirmed case   NaN  30 - 39 Years
# 8405077  Laboratory-confirmed case   NaN  30 - 39 Years
# 8405078  Laboratory-confirmed case   NaN  30 - 39 Years
#
#         Race and ethnicity (combined)  hosp_yn  icu_yn  death_yn  medcond_yn
# 0                 Black, Non-Hispanic      0.0     NaN       0.0         0.0
# 1                 Black, Non-Hispanic      0.0     0.0       0.0         0.0
# 2                 Black, Non-Hispanic      0.0     0.0       0.0         0.0
# 3                 Black, Non-Hispanic      NaN     NaN       0.0         NaN
# 4                 Black, Non-Hispanic      0.0     0.0       0.0         1.0
# ...                               ...      ...     ...       ...         ...
# 8405074                           NaN      0.0     NaN       0.0         NaN
# 8405075                           NaN      NaN     NaN       NaN         NaN
# 8405076                           NaN      NaN     NaN       NaN         NaN
# 8405077                           NaN      NaN     NaN       NaN         NaN
# 8405078                           NaN      0.0     NaN       0.0         NaN
#
# [8405079 rows x 12 columns]

# %%
df = df.dropna()
df
# Out:
#          Unnamed: 0 cdc_report_dt pos_spec_dt    onset_dt  \
# 1                 1    2020/11/14  2020/11/10  2020/11/10
# 2                 2    2020/11/19  2020/11/10  2020/11/09
# 4                 4    2020/11/13  2020/11/10  2020/11/10
# 11               11    2020/11/09  2020/11/10  2020/11/09
# 14               14    2020/11/06  2020/11/10  2020/11/06
# ...             ...           ...         ...         ...
# 7494686     7494686    2020/11/15  2020/11/29  2020/11/15
# 7494687     7494687    2020/11/15  2020/11/29  2020/11/15
# 7494700     7494700    2020/11/18  2020/11/30  2020/11/18
# 7494714     7494714    2020/11/08  2020/11/30  2020/11/08
# 7494730     7494730    2020/11/14  2020/12/02  2020/11/14
#
#                     current_status     sex      age_group  \
# 1        Laboratory-confirmed case    Male  10 - 19 Years
# 2        Laboratory-confirmed case    Male  10 - 19 Years
# 4        Laboratory-confirmed case    Male  10 - 19 Years
# 11       Laboratory-confirmed case    Male  10 - 19 Years
# 14       Laboratory-confirmed case    Male  10 - 19 Years
# ...                            ...     ...            ...
# 7494686  Laboratory-confirmed case  Female  20 - 29 Years
# 7494687  Laboratory-confirmed case  Female  20 - 29 Years
# 7494700  Laboratory-confirmed case    Male  20 - 29 Years
# 7494714  Laboratory-confirmed case    Male  20 - 29 Years
# 7494730  Laboratory-confirmed case  Female  20 - 29 Years
#
#         Race and ethnicity (combined)  hosp_yn  icu_yn  death_yn  medcond_yn
# 1                 Black, Non-Hispanic      0.0     0.0       0.0         0.0
# 2                 Black, Non-Hispanic      0.0     0.0       0.0         0.0
# 4                 Black, Non-Hispanic      0.0     0.0       0.0         1.0
# 11                Black, Non-Hispanic      0.0     0.0       0.0         0.0
# 14                Black, Non-Hispanic      0.0     0.0       0.0         1.0
# ...                               ...      ...     ...       ...         ...
# 7494686           Black, Non-Hispanic      0.0     0.0       0.0         0.0
# 7494687           Black, Non-Hispanic      1.0     0.0       0.0         0.0
# 7494700               Hispanic/Latino      0.0     0.0       0.0         0.0
# 7494714           White, Non-Hispanic      0.0     0.0       0.0         1.0
# 7494730           White, Non-Hispanic      0.0     0.0       0.0         1.0
#
# [294946 rows x 12 columns]
